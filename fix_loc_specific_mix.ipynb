# %%
# %load_ext autoreload
# %autoreload 2

from functools import partial
import numpy as np
import keras
import os

from distributions import ZeroInflatedDist, QuantizedNormal
from plotting_funcs import sample_and_plot, plot_dist, plot_hexagon_grid

import tensorflow as tf
import tensorflow_probability as tfp

import matplotlib.pyplot as plt


seed = 360

from datasets import make_data, train_val_test_split, tensorflow_dataset
from models import poisson_glm, mixture_poissons
from metrics import poisson_nll, get_bpr_loss_func, get_penalized_bpr_loss_func, top_k_idx, mixture_poi_loss, get_penalized_bpr_loss_func_mix, mix_bpr
tf.config.run_functions_eagerly(True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# tracts/distributions
S=12
# history/features
H = 50
# total timepoints
T= 500
# K for bpr
K=3
num_components=4

input_shape = (H,S)

consistent_4 = [QuantizedNormal(7, 0.1) for _ in range(4)]

highvar_4 = [ZeroInflatedDist(QuantizedNormal(10, 0.1), 1-0.7) for _ in range(4)]

powerball_4 = [ZeroInflatedDist(QuantizedNormal(100, 0.1), 0.9) for _ in range(4)]
dist_S = consistent_4 + highvar_4 +powerball_4

sample_and_plot(dist_S, size=1000, median=True, title='Median 1k samples. 4 lottery, 4 consistent, 4 high variance')


X_THS, y_TS = make_data(dist_S, H=H, T=T, seed=360)

# check that each final history is equal to the previous observation
for t in range(H, T):
    assert(np.all(X_THS[t, H-2, :] == y_TS[t-1, :]))

# check random point in history
for t in range(H, T):
    h = np.random.randint(1, H)
    assert(np.all(X_THS[t, h-1, :] == y_TS[t-(H-h), :]))

(train_X_THS, train_y_TS), \
(val_X_THS, val_y_TS), \
(test_X_THS, test_y_TS) = train_val_test_split(X_THS, y_TS, train_pct=0.6, test_pct=0.2)

train_dataset = tensorflow_dataset(train_X_THS, train_y_TS, seed=seed+200,batch_size=100)
val_dataset = tensorflow_dataset(val_X_THS, val_y_TS, seed=seed+300,batch_size=100)

# %%
X_THS[0,:,0]
# Out:
# array([7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.,
#        7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.,
#        7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 1.],
#       dtype=float32)

# %%
input_shape
# Out:
# (50, 12)

# %%
mix_model, mix_weights  = mixture_poissons(poisson_glm, input_shape, num_components=num_components)

# %%
# penalty = 0 for NLL only
penalty = 0
bpr_threshold = 0.45
learning_rate = 0.005

negative_bpr_K = get_bpr_loss_func(K)
penalized_bpr_loss = get_penalized_bpr_loss_func_mix(mixture_poi_loss, K, penalty, bpr_threshold)
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

# %%
#mix_model.compile(optimizer=optimizer, loss=penalized_bpr_loss, metrics = [mix_bpr_metric, mixture_poi_loss])

# %%
preds = mix_model(train_X_THS)

# %%
train_X_THS.shape
# Out:
# (300, 50, 12)

# %%
preds[0].shape
# Out:
# TensorShape([300, 12, 4])

# %%
mix_model.trainable_variables[4]
# Out:
# <tf.Variable 'conv1d_2/kernel:0' shape=(1, 50, 1) dtype=float32, numpy=
# array([[[ 0.13084933],
#         [-0.01157919],
#         [ 0.26785174],
#         [ 0.2131997 ],
#         [ 0.20212999],
#         [ 0.08035618],
#         [ 0.04443347],
#         [ 0.04565915],
#         [ 0.04723394],
#         [-0.17737344],
#         [ 0.02038249],
#         [-0.20093082],
#         [-0.2106985 ],
#         [ 0.12131888],
#         [ 0.32714203],
#         [-0.02962556],
#         [-0.24855752],
#         [ 0.2764509 ],
#         [ 0.04157594],
#         [ 0.2635148 ],
#         [ 0.2747226 ],
#         [-0.24321061],
#         [-0.05461258],
#         [-0.0462288 ],
#         [-0.00102803],
#         [-0.27172697],
#         [-0.18168561],
#         [ 0.27469316],
#         [-0.01652434],
#         [ 0.12850568],
#         [ 0.32052198],
#         [-0.3288783 ],
#         [-0.00714305],
#         [-0.0483788 ],
#         [ 0.23910436],
#         [ 0.19749704],
#         [-0.01127973],
#         [-0.20619152],
#         [-0.15414226],
#         [ 0.16559663],
#         [-0.32603166],
#         [ 0.0516952 ],
#         [-0.09582405],
#         [ 0.29859385],
#         [ 0.2802798 ],
#         [-0.32798997],
#         [ 0.02526513],
#         [-0.17554237],
#         [ 0.18644395],
#         [-0.19870183]]], dtype=float32)>

# %%
mixture_weights.shape
# Out:
# TensorShape([300, 12, 4])

# %%
component_preds, mixture_weights = preds
poisson_nll_fn = partial(tf.nn.log_poisson_loss, train_y_TS, compute_full_loss=True)

# move component dimension to front
swapped = tf.transpose(component_preds, [2,0,1])
log_swapped = tf.math.log(swapped+ 1e-10)

poi_per_component = tf.map_fn(poisson_nll_fn, log_swapped)
poi_per_component = tf.transpose(poi_per_component, [1,2,0])

#mixture_weights = tf.ones((poi_per_component.shape[0],1,1)) * tf.transpose(mixture_weights)

#dot_layer = keras.layers.Dot(axes=[2,2])

mixture_poi_loss_val = tf.einsum('ijk,kj->ij', poi_per_component, mixture_weights)

# %%
mixture_poi_loss_val
# Out:
# <tf.Tensor: shape=(300, 12), dtype=float32, numpy=
# array([[ 48.944683,  48.72837 ,  49.194153, ...,  23.037884,   7.421376,
#         759.5933  ],
#        [ 48.944683,  48.72837 ,  49.194153, ...,  17.12378 ,   4.904865,
#           9.852363],
#        [ 48.944683,  48.72837 ,  49.194153, ...,  21.027765,   4.675223,
#          12.954422],
#        ...,
#        [ 48.944683,  48.72837 ,  49.194153, ...,  25.28842 ,  23.085363,
#          31.26204 ],
#        [ 48.944683,  48.72837 ,  49.194153, ...,  17.78803 ,  12.182643,
#          45.800865],
#        [ 48.944683,  48.72837 ,  49.194153, ...,  18.71412 ,  20.275017,
#          18.070337]], dtype=float32)>

# %%
component_preds, mixture_weights = preds
poisson_nll_fn = partial(tf.nn.log_poisson_loss, train_y_TS, compute_full_loss=True)

# move component dimension to front
swapped = tf.transpose(component_preds, [2,0,1])
log_swapped = tf.math.log(swapped+ 1e-10)

poi_per_component = tf.map_fn(poisson_nll_fn, log_swapped)
poi_per_component = tf.transpose(poi_per_component, [1,2,0])

mixture_weights = tf.ones((poi_per_component.shape[0],1,1)) * tf.transpose(mixture_weights)

dot_layer = keras.layers.Dot(axes=[2,2])

mixture_poi_loss_val = dot_layer([mixture_weights, poi_per_component])

# %%
mixture_poi_loss_val.shape
# Out:
# TensorShape([300, 12, 12])

# %%
tf.einsum('ijk,jl->ilk', mixture_weights, poi_per_component)
# Out:
# 2024-04-28 22:49:48.036671: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at mkl_einsum_op.cc:221 : INVALID_ARGUMENT: Expected input 1 to have rank 2 but got: 3
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 tf.einsum('ijk,jl->ilk', mixture_weights, poi_per_component)
#
# File /cluster/tufts/hugheslab/kheuto01/mambaforge/envs/pip_k2_tf/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /cluster/tufts/hugheslab/kheuto01/mambaforge/envs/pip_k2_tf/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:5883, in raise_from_not_ok_status(e, name)
#    5881 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5882   e.message += (" name: " + str(name if name is not None else ""))
# -> 5883   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: {{function_node __wrapped____MklEinsum_N_2_device_/job:localhost/replica:0/task:0/device:CPU:0}} Expected input 1 to have rank 2 but got: 3 [Op:Einsum] name:

# %%
mixture_poi_loss_val
# Out:
# <tf.Tensor: shape=(300, 12, 12), dtype=float32, numpy=
# array([[[ 48.944683 ,  48.944683 ,  48.944683 , ...,  23.360323 ,
#            7.4748974, 768.24176  ],
#         [ 48.72837  ,  48.72837  ,  48.72837  , ...,  22.894632 ,
#            7.338909 , 791.3533   ],
#         [ 49.194153 ,  49.194153 ,  49.194153 , ...,  23.007524 ,
#            7.602507 , 754.28503  ],
#         ...,
#         [ 47.4649   ,  47.4649   ,  47.4649   , ...,  23.037884 ,
#            7.455067 , 812.7489   ],
#         [ 47.92107  ,  47.92107  ,  47.92107  , ...,  23.273148 ,
#            7.421376 , 801.03357  ],
#         [ 49.67028  ,  49.67028  ,  49.67028  , ...,  23.278208 ,
#            7.3673263, 759.5933   ]],
#
#        [[ 48.944683 ,  48.944683 ,  48.944683 , ...,  16.96642  ,
#            4.9402485,   9.907272 ],
#         [ 48.72837  ,  48.72837  ,  48.72837  , ...,  17.125813 ,
#            4.8503575,   9.836772 ],
#         [ 49.194153 ,  49.194153 ,  49.194153 , ...,  16.835308 ,
#            5.024567 ,   9.72777  ],
#         ...,
#         [ 47.4649   ,  47.4649   ,  47.4649   , ...,  17.12378  ,
#            4.927114 ,   9.95906  ],
#         [ 47.92107  ,  47.92107  ,  47.92107  , ...,  17.108608 ,
#            4.904865 ,   9.999458 ],
#         [ 49.67028  ,  49.67028  ,  49.67028  , ...,  17.00579  ,
#            4.869164 ,   9.852363 ]],
#
#        [[ 48.944683 ,  48.944683 ,  48.944683 , ...,  20.062807 ,
#            4.692531 ,  13.092243 ],
#         [ 48.72837  ,  48.72837  ,  48.72837  , ...,  20.449299 ,
#            4.6749926,  13.329667 ],
#         [ 49.194153 ,  49.194153 ,  49.194153 , ...,  19.857876 ,
#            4.665251 ,  12.817144 ],
#         ...,
#         [ 47.4649   ,  47.4649   ,  47.4649   , ...,  21.027765 ,
#            4.651208 ,  13.661922 ],
#         [ 47.92107  ,  47.92107  ,  47.92107  , ...,  20.742548 ,
#            4.675223 ,  13.543897 ],
#         [ 49.67028  ,  49.67028  ,  49.67028  , ...,  19.775814 ,
#            4.7099133,  12.954422 ]],
#
#        ...,
#
#        [[ 48.944683 ,  48.944683 ,  48.944683 , ...,  24.299362 ,
#           22.592112 ,  31.419653 ],
#         [ 48.72837  ,  48.72837  ,  48.72837  , ...,  24.696905 ,
#           22.778915 ,  30.736164 ],
#         [ 49.194153 ,  49.194153 ,  49.194153 , ...,  23.795414 ,
#           22.54232  ,  31.131353 ],
#         ...,
#         [ 47.4649   ,  47.4649   ,  47.4649   , ...,  25.28842  ,
#           23.342154 ,  30.946562 ],
#         [ 47.92107  ,  47.92107  ,  47.92107  , ...,  25.092216 ,
#           23.085363 ,  31.216724 ],
#         [ 49.67028  ,  49.67028  ,  49.67028  , ...,  24.053612 ,
#           22.268362 ,  31.26204  ]],
#
#        [[ 48.944683 ,  48.944683 ,  48.944683 , ...,  17.304466 ,
#           11.925187 ,  46.300175 ],
#         [ 48.72837  ,  48.72837  ,  48.72837  , ...,  17.837608 ,
#           12.301262 ,  46.106922 ],
#         [ 49.194153 ,  49.194153 ,  49.194153 , ...,  17.270287 ,
#           11.877559 ,  46.399406 ],
#         ...,
#         [ 47.4649   ,  47.4649   ,  47.4649   , ...,  17.78803  ,
#           12.30836  ,  46.848083 ],
#         [ 47.92107  ,  47.92107  ,  47.92107  , ...,  17.62052  ,
#           12.182643 ,  46.618237 ],
#         [ 49.67028  ,  49.67028  ,  49.67028  , ...,  17.397669 ,
#           11.968457 ,  45.800865 ]],
#
#        [[ 48.944683 ,  48.944683 ,  48.944683 , ...,  19.499163 ,
#           20.653917 ,  18.056509 ],
#         [ 48.72837  ,  48.72837  ,  48.72837  , ...,  18.973198 ,
#           20.162771 ,  18.098873 ],
#         [ 49.194153 ,  49.194153 ,  49.194153 , ...,  19.366053 ,
#           20.668491 ,  18.229212 ],
#         ...,
#         [ 47.4649   ,  47.4649   ,  47.4649   , ...,  18.71412  ,
#           20.06214  ,  18.039345 ],
#         [ 47.92107  ,  47.92107  ,  47.92107  , ...,  19.045591 ,
#           20.275017 ,  17.988796 ],
#         [ 49.67028  ,  49.67028  ,  49.67028  , ...,  19.626406 ,
#           20.662127 ,  18.070337 ]]], dtype=float32)>

# %%
mixture_weights
# Out:
# <tf.Tensor: shape=(300, 12, 4), dtype=float32, numpy=
# array([[[0.24930684, 0.24424917, 0.24413565, 0.26230845],
#         [0.2553737 , 0.23980562, 0.25318497, 0.25163567],
#         [0.25453982, 0.24841893, 0.23847607, 0.25856513],
#         ...,
#         [0.2443048 , 0.24360119, 0.2617666 , 0.2503275 ],
#         [0.24436733, 0.2425003 , 0.25716922, 0.25596315],
#         [0.25601956, 0.24073417, 0.24065328, 0.26259297]],
#
#        [[0.24930684, 0.24424917, 0.24413565, 0.26230845],
#         [0.2553737 , 0.23980562, 0.25318497, 0.25163567],
#         [0.25453982, 0.24841893, 0.23847607, 0.25856513],
#         ...,
#         [0.2443048 , 0.24360119, 0.2617666 , 0.2503275 ],
#         [0.24436733, 0.2425003 , 0.25716922, 0.25596315],
#         [0.25601956, 0.24073417, 0.24065328, 0.26259297]],
#
#        [[0.24930684, 0.24424917, 0.24413565, 0.26230845],
#         [0.2553737 , 0.23980562, 0.25318497, 0.25163567],
#         [0.25453982, 0.24841893, 0.23847607, 0.25856513],
#         ...,
#         [0.2443048 , 0.24360119, 0.2617666 , 0.2503275 ],
#         [0.24436733, 0.2425003 , 0.25716922, 0.25596315],
#         [0.25601956, 0.24073417, 0.24065328, 0.26259297]],
#
#        ...,
#
#        [[0.24930684, 0.24424917, 0.24413565, 0.26230845],
#         [0.2553737 , 0.23980562, 0.25318497, 0.25163567],
#         [0.25453982, 0.24841893, 0.23847607, 0.25856513],
#         ...,
#         [0.2443048 , 0.24360119, 0.2617666 , 0.2503275 ],
#         [0.24436733, 0.2425003 , 0.25716922, 0.25596315],
#         [0.25601956, 0.24073417, 0.24065328, 0.26259297]],
#
#        [[0.24930684, 0.24424917, 0.24413565, 0.26230845],
#         [0.2553737 , 0.23980562, 0.25318497, 0.25163567],
#         [0.25453982, 0.24841893, 0.23847607, 0.25856513],
#         ...,
#         [0.2443048 , 0.24360119, 0.2617666 , 0.2503275 ],
#         [0.24436733, 0.2425003 , 0.25716922, 0.25596315],
#         [0.25601956, 0.24073417, 0.24065328, 0.26259297]],
#
#        [[0.24930684, 0.24424917, 0.24413565, 0.26230845],
#         [0.2553737 , 0.23980562, 0.25318497, 0.25163567],
#         [0.25453982, 0.24841893, 0.23847607, 0.25856513],
#         ...,
#         [0.2443048 , 0.24360119, 0.2617666 , 0.2503275 ],
#         [0.24436733, 0.2425003 , 0.25716922, 0.25596315],
#         [0.25601956, 0.24073417, 0.24065328, 0.26259297]]], dtype=float32)>

# %%
def training_loop(model, loss_func, optimizer, num_epochs, verbose=False):

    losses = {}
    losses['train'] = {}
    losses['val'] ={}
    losses['train']['loss']=[]
    losses['train']['nll']=[]
    losses['train']['bpr']=[]
    losses['val']['loss']=[]
    losses['val']['nll']=[]
    losses['val']['bpr']=[]

    for epoch in range(num_epochs):

        for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
            # Open a GradientTape to record the operations run
            # during the forward pass, which enables auto-differentiation.
            with tf.GradientTape() as tape:
                y_preds = model(x_batch_train, training=True)
                loss_value = loss_func(y_batch_train, y_preds)
                
            # Use the gradient tape to automatically retrieve
            # the gradients of the trainable variables with respect to the loss.
            grads = tape.gradient(loss_value, model.trainable_weights)

            # Run one step of gradient descent by updating
            # the value of the variables to minimize the loss.
            optimizer.apply_gradients(zip(grads, model.trainable_weights))

        y_preds = model(train_X_THS)
        loss = loss_func(train_y_TS, y_preds)
        loss = tf.reduce_mean(loss)
        bpr = mix_bpr(train_y_TS, y_preds, negative_bpr_K_func=negative_bpr_K)
        nll = mixture_poi_loss(train_y_TS, y_preds)
        nll = tf.reduce_mean(tf.reduce_sum(nll,axis=-1))
        losses['train']['loss'].append(loss)
        losses['train']['nll'].append(nll)
        losses['train']['bpr'].append(bpr)
        if verbose:
            print(f'{epoch}: {loss}')
        y_preds = model(val_X_THS)
        loss = loss_func(val_y_TS, y_preds)
        loss = tf.reduce_mean(loss)
        bpr = mix_bpr(val_y_TS, y_preds, negative_bpr_K_func=negative_bpr_K)
        nll = mixture_poi_loss(val_y_TS, y_preds)
        nll = tf.reduce_mean(tf.reduce_sum(nll,axis=-1))
        losses['val']['loss'].append(loss)
        losses['val']['nll'].append(nll)
        losses['val']['bpr'].append(bpr)

    return losses

# %%
losses = training_loop(mix_model, penalized_bpr_loss, optimizer, 100, verbose=True)
# Out:
# 0: 747.3442993164062
# 1: 584.021240234375
# 2: 467.21343994140625
# 3: 406.08648681640625
# 4: 372.89959716796875
# 5: 351.36029052734375
# 6: 335.2935791015625
# 7: 322.4259338378906
# 8: 311.28399658203125
# 9: 300.88623046875
# 10: 290.4627380371094
# 11: 280.57843017578125
# 12: 271.50238037109375

# %%
def plot_losses(losses, title_add='', save_dir=None, file_add=''):
    # plot loss and metrics from history
    plt.plot(losses['train']['loss'])
    plt.plot(losses['val']['loss'])
    plt.title(f'Model loss {title_add}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()
    if save_dir is not None:
        plt.savefig(os.path.join(save_dir, f'loss_{file_add}.png'))

    plt.plot(losses['train']['nll'])
    plt.plot(losses['val']['nll'])
    plt.title(f'Model NLL {title_add}')
    plt.ylabel('NLL')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()
    if save_dir is not None:
        plt.savefig(os.path.join(save_dir, f'nll_{file_add}.png'))

    plt.plot(losses['train']['bpr'])
    plt.plot(losses['val']['bpr'])
    plt.title(f'Model Negative BPR {title_add}')
    plt.ylabel('Negative BPR')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()
    if save_dir is not None:
        plt.savefig(os.path.join(save_dir, f'bpr_{file_add}.png'))

# %%
plot_losses(losses, 'NLL Only model')

# %%
from functools import partial
val_preds, mix_weights = mix_model(val_X_THS)

mixture_weights = tf.ones((val_preds.shape[0],1)) * tf.squeeze(mix_weights)
dot_layer = keras.layers.Dot(axes=(1,-1))
mixture_pred = dot_layer([mixture_weights, val_preds])

# get one hot vector of top 3 values in val_preds
top_K_idx_func = partial(top_k_idx, k=K)
top_K_ids = top_K_idx_func(mixture_pred)
print(f'avg pred:{np.mean(top_K_ids, axis=0)}')
print(f'avg pred per component: {tf.reduce_mean(tf.map_fn(top_K_idx_func, tf.transpose(val_preds,(2,0,1))), axis=1)}')
# Out:
# avg pred:[0.06 0.   0.   0.3  0.28 0.4  0.4  0.38 0.22 0.24 0.38 0.34]
# avg pred per component: [[0.08 0.   0.39 0.07 0.27 0.5  0.43 0.33 0.21 0.19 0.3  0.23]
#  [0.02 0.1  0.   0.37 0.28 0.39 0.42 0.42 0.18 0.18 0.28 0.36]
#  [0.37 0.01 0.13 0.01 0.26 0.57 0.34 0.27 0.21 0.27 0.33 0.23]
#  [0.07 0.06 0.02 0.46 0.24 0.42 0.41 0.45 0.16 0.21 0.25 0.25]]

# %%
mix_model, mix_weights  = mixture_poissons(input_shape, num_components=num_components)
# penalty = 500 for penalized objective 
penalty = 500
bpr_threshold = 0.45
learning_rate = 0.01

negative_bpr_K = get_bpr_loss_func(K)
penalized_bpr_loss = get_penalized_bpr_loss_func_mix(mixture_poi_loss, K, penalty, bpr_threshold)
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

losses_penalized = training_loop(mix_model, penalized_bpr_loss, optimizer, 100)
# Out:
# Start of epoch 0
# tf.Tensor(658.3053, shape=(), dtype=float32)
#
# Start of epoch 1
# tf.Tensor(511.3529, shape=(), dtype=float32)
#
# Start of epoch 2
# tf.Tensor(463.50912, shape=(), dtype=float32)
#
# Start of epoch 3
# tf.Tensor(444.22412, shape=(), dtype=float32)
#
# Start of epoch 4
# tf.Tensor(428.89835, shape=(), dtype=float32)
#
# Start of epoch 5
# tf.Tensor(413.85822, shape=(), dtype=float32)
#
# Start of epoch 6
# tf.Tensor(399.18924, shape=(), dtype=float32)
#
# Start of epoch 7
# tf.Tensor(383.18253, shape=(), dtype=float32)
#
# Start of epoch 8
# tf.Tensor(367.35324, shape=(), dtype=float32)
#
# Start of epoch 9
# tf.Tensor(352.09183, shape=(), dtype=float32)
#
# Start of epoch 10
# tf.Tensor(333.43677, shape=(), dtype=float32)
#
# Start of epoch 11
# tf.Tensor(312.53207, shape=(), dtype=float32)
#
# Start of epoch 12
# tf.Tensor(294.29022, shape=(), dtype=float32)
#
# Start of epoch 13
# tf.Tensor(278.08762, shape=(), dtype=float32)
#
# Start of epoch 14
# tf.Tensor(262.65662, shape=(), dtype=float32)
#
# Start of epoch 15
# tf.Tensor(247.42792, shape=(), dtype=float32)
#
# Start of epoch 16
# tf.Tensor(232.84172, shape=(), dtype=float32)
#
# Start of epoch 17
# tf.Tensor(221.84357, shape=(), dtype=float32)
#
# Start of epoch 18
# tf.Tensor(211.64699, shape=(), dtype=float32)
#
# Start of epoch 19
# tf.Tensor(202.89925, shape=(), dtype=float32)
#
# Start of epoch 20
# tf.Tensor(193.5964, shape=(), dtype=float32)
#
# Start of epoch 21
# tf.Tensor(183.82793, shape=(), dtype=float32)
#
# Start of epoch 22
# tf.Tensor(175.70355, shape=(), dtype=float32)
#
# Start of epoch 23
# tf.Tensor(170.40025, shape=(), dtype=float32)
#
# Start of epoch 24
# tf.Tensor(164.12877, shape=(), dtype=float32)
#
# Start of epoch 25
# tf.Tensor(159.58151, shape=(), dtype=float32)
#
# Start of epoch 26
# tf.Tensor(158.85243, shape=(), dtype=float32)
#
# Start of epoch 27
# tf.Tensor(155.07507, shape=(), dtype=float32)
#
# Start of epoch 28
# tf.Tensor(149.46858, shape=(), dtype=float32)
#
# Start of epoch 29
# tf.Tensor(146.17049, shape=(), dtype=float32)
#
# Start of epoch 30
# tf.Tensor(144.52481, shape=(), dtype=float32)
#
# Start of epoch 31
# tf.Tensor(141.21811, shape=(), dtype=float32)
#
# Start of epoch 32
# tf.Tensor(136.32088, shape=(), dtype=float32)
#
# Start of epoch 33
# tf.Tensor(132.72946, shape=(), dtype=float32)
#
# Start of epoch 34
# tf.Tensor(131.87933, shape=(), dtype=float32)
#
# Start of epoch 35
# tf.Tensor(130.92426, shape=(), dtype=float32)
#
# Start of epoch 36
# tf.Tensor(128.09149, shape=(), dtype=float32)
#
# Start of epoch 37
# tf.Tensor(124.932594, shape=(), dtype=float32)
#
# Start of epoch 38
# tf.Tensor(124.512985, shape=(), dtype=float32)
#
# Start of epoch 39
# tf.Tensor(121.7877, shape=(), dtype=float32)
#
# Start of epoch 40
# tf.Tensor(121.404495, shape=(), dtype=float32)
#
# Start of epoch 41
# tf.Tensor(120.860016, shape=(), dtype=float32)
#
# Start of epoch 42
# tf.Tensor(119.62341, shape=(), dtype=float32)
#
# Start of epoch 43
# tf.Tensor(117.773346, shape=(), dtype=float32)
#
# Start of epoch 44
# tf.Tensor(116.34441, shape=(), dtype=float32)
#
# Start of epoch 45
# tf.Tensor(115.60168, shape=(), dtype=float32)
#
# Start of epoch 46
# tf.Tensor(114.71134, shape=(), dtype=float32)
#
# Start of epoch 47
# tf.Tensor(114.798386, shape=(), dtype=float32)
#
# Start of epoch 48
# tf.Tensor(114.61543, shape=(), dtype=float32)
#
# Start of epoch 49
# tf.Tensor(115.12209, shape=(), dtype=float32)
#
# Start of epoch 50
# tf.Tensor(113.63381, shape=(), dtype=float32)
#
# Start of epoch 51
# tf.Tensor(113.15525, shape=(), dtype=float32)
#
# Start of epoch 52
# tf.Tensor(113.206604, shape=(), dtype=float32)
#
# Start of epoch 53
# tf.Tensor(113.22108, shape=(), dtype=float32)
#
# Start of epoch 54
# tf.Tensor(112.44074, shape=(), dtype=float32)
#
# Start of epoch 55
# tf.Tensor(112.03562, shape=(), dtype=float32)
#
# Start of epoch 56
# tf.Tensor(111.6318, shape=(), dtype=float32)
#
# Start of epoch 57
# tf.Tensor(111.30858, shape=(), dtype=float32)
#
# Start of epoch 58
# tf.Tensor(111.65962, shape=(), dtype=float32)
#
# Start of epoch 59
# tf.Tensor(111.551056, shape=(), dtype=float32)
#
# Start of epoch 60
# tf.Tensor(110.90439, shape=(), dtype=float32)
#
# Start of epoch 61
# tf.Tensor(111.48086, shape=(), dtype=float32)
#
# Start of epoch 62
# tf.Tensor(111.694885, shape=(), dtype=float32)
#
# Start of epoch 63
# tf.Tensor(111.06038, shape=(), dtype=float32)
#
# Start of epoch 64
# tf.Tensor(111.58767, shape=(), dtype=float32)
#
# Start of epoch 65
# tf.Tensor(111.25774, shape=(), dtype=float32)
#
# Start of epoch 66
# tf.Tensor(111.386185, shape=(), dtype=float32)
#
# Start of epoch 67
# tf.Tensor(110.52967, shape=(), dtype=float32)
#
# Start of epoch 68
# tf.Tensor(109.896225, shape=(), dtype=float32)
#
# Start of epoch 69
# tf.Tensor(109.40708, shape=(), dtype=float32)
#
# Start of epoch 70
# tf.Tensor(108.94016, shape=(), dtype=float32)
#
# Start of epoch 71
# tf.Tensor(109.1624, shape=(), dtype=float32)
#
# Start of epoch 72
# tf.Tensor(109.89901, shape=(), dtype=float32)
#
# Start of epoch 73
# tf.Tensor(109.8748, shape=(), dtype=float32)
#
# Start of epoch 74
# tf.Tensor(108.926506, shape=(), dtype=float32)
#
# Start of epoch 75
# tf.Tensor(109.87275, shape=(), dtype=float32)
#
# Start of epoch 76
# tf.Tensor(111.2247, shape=(), dtype=float32)
#
# Start of epoch 77
# tf.Tensor(109.19935, shape=(), dtype=float32)
#
# Start of epoch 78
# tf.Tensor(107.95287, shape=(), dtype=float32)
#
# Start of epoch 79
# tf.Tensor(107.92522, shape=(), dtype=float32)
#
# Start of epoch 80
# tf.Tensor(107.84969, shape=(), dtype=float32)
#
# Start of epoch 81
# tf.Tensor(109.29778, shape=(), dtype=float32)
#
# Start of epoch 82
# tf.Tensor(110.13008, shape=(), dtype=float32)
#
# Start of epoch 83
# tf.Tensor(108.92066, shape=(), dtype=float32)
#
# Start of epoch 84
# tf.Tensor(108.89141, shape=(), dtype=float32)
#
# Start of epoch 85
# tf.Tensor(108.74699, shape=(), dtype=float32)
#
# Start of epoch 86
# tf.Tensor(108.261246, shape=(), dtype=float32)
#
# Start of epoch 87
# tf.Tensor(107.8396, shape=(), dtype=float32)
#
# Start of epoch 88
# tf.Tensor(107.59779, shape=(), dtype=float32)
#
# Start of epoch 89
# tf.Tensor(107.566826, shape=(), dtype=float32)
#
# Start of epoch 90
# tf.Tensor(107.18967, shape=(), dtype=float32)
#
# Start of epoch 91
# tf.Tensor(107.511246, shape=(), dtype=float32)
#
# Start of epoch 92
# tf.Tensor(107.84543, shape=(), dtype=float32)
#
# Start of epoch 93
# tf.Tensor(107.47077, shape=(), dtype=float32)
#
# Start of epoch 94
# tf.Tensor(107.39761, shape=(), dtype=float32)
#
# Start of epoch 95
# tf.Tensor(107.35057, shape=(), dtype=float32)
#
# Start of epoch 96
# tf.Tensor(107.25393, shape=(), dtype=float32)
#
# Start of epoch 97
# tf.Tensor(107.719055, shape=(), dtype=float32)
#
# Start of epoch 98
# tf.Tensor(107.45154, shape=(), dtype=float32)
#
# Start of epoch 99
# tf.Tensor(106.958565, shape=(), dtype=float32)

# %%
plot_losses(losses_penalized, 'Penalized model')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 plot_losses(losses, 'NLL Only model')
#
# NameError: name 'plot_losses' is not defined

# %%
from functools import partial
val_preds, mix_weights = mix_model(val_X_THS)

mixture_weights = tf.ones((val_preds.shape[0],1)) * tf.squeeze(mix_weights)
dot_layer = keras.layers.Dot(axes=(1,-1))
mixture_pred = dot_layer([mixture_weights, val_preds])

# get one hot vector of top 3 values in val_preds
top_K_idx_func = partial(top_k_idx, k=K)
top_K_ids = top_K_idx_func(mixture_pred)
print(f'avg pred:{np.mean(top_K_ids, axis=0)}')
print(f'avg pred per component: {tf.reduce_mean(tf.map_fn(top_K_idx_func, tf.transpose(val_preds,(2,0,1))), axis=1)}')
# Out:
# avg pred:[0.17 0.04 0.   0.   0.14 0.23 0.24 0.22 0.5  0.53 0.51 0.42]
# avg pred per component: [[0.19 0.03 0.   0.   0.15 0.27 0.25 0.17 0.53 0.54 0.49 0.38]
#  [0.14 0.04 0.   0.   0.15 0.25 0.24 0.2  0.5  0.53 0.51 0.44]
#  [0.16 0.04 0.   0.   0.15 0.24 0.24 0.21 0.49 0.52 0.51 0.44]
#  [0.18 0.03 0.   0.   0.13 0.26 0.26 0.19 0.53 0.53 0.48 0.41]]

# %%
mix_model, mix_weights  = mixture_poissons(input_shape, num_components=num_components)
# penalty = 1 because BPR is only objective
penalty = 1
bpr_threshold = 0.45
learning_rate = 0.01

negative_bpr_K = get_bpr_loss_func(K)
bpr_only_loss = partial(mix_bpr, negative_bpr_K_func=negative_bpr_K)
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

losses_bpr = training_loop(mix_model, bpr_only_loss, optimizer, 100)
plot_losses(losses_bpr, 'BPR Only model')
from functools import partial
val_preds, mix_weights = mix_model(val_X_THS)

mixture_weights = tf.ones((val_preds.shape[0],1)) * tf.squeeze(mix_weights)
dot_layer = keras.layers.Dot(axes=(1,-1))
mixture_pred = dot_layer([mixture_weights, val_preds])

# get one hot vector of top 3 values in val_preds
top_K_idx_func = partial(top_k_idx, k=K)
top_K_ids = top_K_idx_func(mixture_pred)
print(f'avg pred:{np.mean(top_K_ids, axis=0)}')
print(f'avg pred per component: {tf.reduce_mean(tf.map_fn(top_K_idx_func, tf.transpose(val_preds,(2,0,1))), axis=1)}')
# Out:
# Start of epoch 0
# tf.Tensor(-0.26250917, shape=(), dtype=float32)
#
# Start of epoch 1
# tf.Tensor(-0.2882908, shape=(), dtype=float32)
#
# Start of epoch 2
# tf.Tensor(-0.30679497, shape=(), dtype=float32)
#
# Start of epoch 3
# tf.Tensor(-0.32369322, shape=(), dtype=float32)
#
# Start of epoch 4
# tf.Tensor(-0.3354163, shape=(), dtype=float32)
#
# Start of epoch 5
# tf.Tensor(-0.34474602, shape=(), dtype=float32)
#
# Start of epoch 6
# tf.Tensor(-0.35269722, shape=(), dtype=float32)
#
# Start of epoch 7
# tf.Tensor(-0.3595072, shape=(), dtype=float32)
#
# Start of epoch 8
# tf.Tensor(-0.3657574, shape=(), dtype=float32)
#
# Start of epoch 9
# tf.Tensor(-0.3701406, shape=(), dtype=float32)
#
# Start of epoch 10
# tf.Tensor(-0.37617007, shape=(), dtype=float32)
#
# Start of epoch 11
# tf.Tensor(-0.38051873, shape=(), dtype=float32)
#
# Start of epoch 12
# tf.Tensor(-0.38422748, shape=(), dtype=float32)
#
# Start of epoch 13
# tf.Tensor(-0.38817796, shape=(), dtype=float32)
#
# Start of epoch 14
# tf.Tensor(-0.39218095, shape=(), dtype=float32)
#
# Start of epoch 15
# tf.Tensor(-0.39766532, shape=(), dtype=float32)
#
# Start of epoch 16
# tf.Tensor(-0.40445298, shape=(), dtype=float32)
#
# Start of epoch 17
# tf.Tensor(-0.4092451, shape=(), dtype=float32)
#
# Start of epoch 18
# tf.Tensor(-0.41161278, shape=(), dtype=float32)
#
# Start of epoch 19
# tf.Tensor(-0.41317508, shape=(), dtype=float32)
#
# Start of epoch 20
# tf.Tensor(-0.415279, shape=(), dtype=float32)
#
# Start of epoch 21
# tf.Tensor(-0.4173483, shape=(), dtype=float32)
#
# Start of epoch 22
# tf.Tensor(-0.4182788, shape=(), dtype=float32)
#
# Start of epoch 23
# tf.Tensor(-0.4192995, shape=(), dtype=float32)
#
# Start of epoch 24
# tf.Tensor(-0.4217568, shape=(), dtype=float32)
#
# Start of epoch 25
# tf.Tensor(-0.4230339, shape=(), dtype=float32)
#
# Start of epoch 26
# tf.Tensor(-0.42495203, shape=(), dtype=float32)
#
# Start of epoch 27
# tf.Tensor(-0.42605788, shape=(), dtype=float32)
#
# Start of epoch 28
# tf.Tensor(-0.42802665, shape=(), dtype=float32)
#
# Start of epoch 29
# tf.Tensor(-0.4293512, shape=(), dtype=float32)
#
# Start of epoch 30
# tf.Tensor(-0.43155253, shape=(), dtype=float32)
#
# Start of epoch 31
# tf.Tensor(-0.4336214, shape=(), dtype=float32)
#
# Start of epoch 32
# tf.Tensor(-0.4361358, shape=(), dtype=float32)
#
# Start of epoch 33
# tf.Tensor(-0.4370578, shape=(), dtype=float32)
#
# Start of epoch 34
# tf.Tensor(-0.43802592, shape=(), dtype=float32)
#
# Start of epoch 35
# tf.Tensor(-0.4397907, shape=(), dtype=float32)
#
# Start of epoch 36
# tf.Tensor(-0.43998647, shape=(), dtype=float32)
#
# Start of epoch 37
# tf.Tensor(-0.44017136, shape=(), dtype=float32)
#
# Start of epoch 38
# tf.Tensor(-0.44046828, shape=(), dtype=float32)
#
# Start of epoch 39
# tf.Tensor(-0.44146866, shape=(), dtype=float32)
#
# Start of epoch 40
# tf.Tensor(-0.44172618, shape=(), dtype=float32)
#
# Start of epoch 41
# tf.Tensor(-0.44362497, shape=(), dtype=float32)
#
# Start of epoch 42
# tf.Tensor(-0.44480824, shape=(), dtype=float32)
#
# Start of epoch 43
# tf.Tensor(-0.4444279, shape=(), dtype=float32)
#
# Start of epoch 44
# tf.Tensor(-0.4458585, shape=(), dtype=float32)
#
# Start of epoch 45
# tf.Tensor(-0.44607136, shape=(), dtype=float32)
#
# Start of epoch 46
# tf.Tensor(-0.4464305, shape=(), dtype=float32)
#
# Start of epoch 47
# tf.Tensor(-0.44711015, shape=(), dtype=float32)
#
# Start of epoch 48
# tf.Tensor(-0.44936883, shape=(), dtype=float32)
#
# Start of epoch 49
# tf.Tensor(-0.45017445, shape=(), dtype=float32)
#
# Start of epoch 50
# tf.Tensor(-0.4506605, shape=(), dtype=float32)
#
# Start of epoch 51
# tf.Tensor(-0.45033762, shape=(), dtype=float32)
#
# Start of epoch 52
# tf.Tensor(-0.45158458, shape=(), dtype=float32)
#
# Start of epoch 53
# tf.Tensor(-0.45205906, shape=(), dtype=float32)
#
# Start of epoch 54
# tf.Tensor(-0.4523822, shape=(), dtype=float32)
#
# Start of epoch 55
# tf.Tensor(-0.45477727, shape=(), dtype=float32)
#
# Start of epoch 56
# tf.Tensor(-0.45573562, shape=(), dtype=float32)
#
# Start of epoch 57
# tf.Tensor(-0.4566742, shape=(), dtype=float32)
#
# Start of epoch 58
# tf.Tensor(-0.45838246, shape=(), dtype=float32)
#
# Start of epoch 59
# tf.Tensor(-0.45854655, shape=(), dtype=float32)
#
# Start of epoch 60
# tf.Tensor(-0.45975244, shape=(), dtype=float32)
#
# Start of epoch 61
# tf.Tensor(-0.4606986, shape=(), dtype=float32)
#
# Start of epoch 62
# tf.Tensor(-0.46137783, shape=(), dtype=float32)
#
# Start of epoch 63
# tf.Tensor(-0.4617136, shape=(), dtype=float32)
#
# Start of epoch 64
# tf.Tensor(-0.46204457, shape=(), dtype=float32)
#
# Start of epoch 65
# tf.Tensor(-0.46243525, shape=(), dtype=float32)
#
# Start of epoch 66
# tf.Tensor(-0.46313536, shape=(), dtype=float32)
#
# Start of epoch 67
# tf.Tensor(-0.46237278, shape=(), dtype=float32)
#
# Start of epoch 68
# tf.Tensor(-0.46208096, shape=(), dtype=float32)
#
# Start of epoch 69
# tf.Tensor(-0.46237975, shape=(), dtype=float32)
#
# Start of epoch 70
# tf.Tensor(-0.46261272, shape=(), dtype=float32)
#
# Start of epoch 71
# tf.Tensor(-0.46425116, shape=(), dtype=float32)
#
# Start of epoch 72
# tf.Tensor(-0.4664247, shape=(), dtype=float32)
#
# Start of epoch 73
# tf.Tensor(-0.46593466, shape=(), dtype=float32)
#
# Start of epoch 74
# tf.Tensor(-0.46536738, shape=(), dtype=float32)
#
# Start of epoch 75
# tf.Tensor(-0.46431813, shape=(), dtype=float32)
#
# Start of epoch 76
# tf.Tensor(-0.4676065, shape=(), dtype=float32)
#
# Start of epoch 77
# tf.Tensor(-0.46936223, shape=(), dtype=float32)
#
# Start of epoch 78
# tf.Tensor(-0.46932125, shape=(), dtype=float32)
#
# Start of epoch 79
# tf.Tensor(-0.46997294, shape=(), dtype=float32)
#
# Start of epoch 80
# tf.Tensor(-0.47021326, shape=(), dtype=float32)
#
# Start of epoch 81
# tf.Tensor(-0.46713227, shape=(), dtype=float32)
#
# Start of epoch 82
# tf.Tensor(-0.46579802, shape=(), dtype=float32)
#
# Start of epoch 83
# tf.Tensor(-0.47078228, shape=(), dtype=float32)
#
# Start of epoch 84
# tf.Tensor(-0.47131392, shape=(), dtype=float32)
#
# Start of epoch 85
# tf.Tensor(-0.4705245, shape=(), dtype=float32)
#
# Start of epoch 86
# tf.Tensor(-0.4698705, shape=(), dtype=float32)
#
# Start of epoch 87
# tf.Tensor(-0.4703141, shape=(), dtype=float32)
#
# Start of epoch 88
# tf.Tensor(-0.47008443, shape=(), dtype=float32)
#
# Start of epoch 89
# tf.Tensor(-0.47169825, shape=(), dtype=float32)
#
# Start of epoch 90
# tf.Tensor(-0.4720664, shape=(), dtype=float32)
#
# Start of epoch 91
# tf.Tensor(-0.47288793, shape=(), dtype=float32)
#
# Start of epoch 92
# tf.Tensor(-0.47310948, shape=(), dtype=float32)
#
# Start of epoch 93
# tf.Tensor(-0.47392908, shape=(), dtype=float32)
#
# Start of epoch 94
# tf.Tensor(-0.47549647, shape=(), dtype=float32)
#
# Start of epoch 95
# tf.Tensor(-0.47726506, shape=(), dtype=float32)
#
# Start of epoch 96
# tf.Tensor(-0.47749445, shape=(), dtype=float32)
#
# Start of epoch 97
# tf.Tensor(-0.47573984, shape=(), dtype=float32)
#
# Start of epoch 98
# tf.Tensor(-0.47616792, shape=(), dtype=float32)
#
# Start of epoch 99
# tf.Tensor(-0.4770951, shape=(), dtype=float32)
# avg pred:[0.09 0.   0.   0.   0.2  0.2  0.2  0.2  0.53 0.52 0.5  0.56]
# avg pred per component: [[0.1  0.03 0.   0.   0.47 0.23 0.23 0.27 0.4  0.38 0.38 0.51]
#  [0.16 0.06 0.   0.   0.16 0.23 0.25 0.21 0.47 0.51 0.5  0.45]
#  [0.09 0.02 0.   0.   0.24 0.23 0.25 0.26 0.52 0.49 0.46 0.44]
#  [0.1  0.01 0.   0.   0.63 0.25 0.24 0.32 0.38 0.28 0.37 0.42]]

# %%
plt.plot(-np.array(losses['val']['nll'][-1]), -np.array(losses['val']['bpr'][-1]), marker='o', label='NLL')
plt.plot(-np.array(losses_bpr['val']['nll'][-1]), -np.array(losses_bpr['val']['bpr'][-1]), marker='o', label='BPR')
plt.plot(-np.array(losses_penalized['val']['nll'][-1]), -np.array(losses_penalized['val']['bpr'][-1]), marker='o', label='Penalized')
plt.title('Validation Frontier')
plt.legend()
plt.show()

plt.plot(-np.array(losses['train']['nll'][-1]), -np.array(losses['train']['bpr'][-1]), marker='o', label='NLL')
plt.plot(-np.array(losses_bpr['train']['nll'][-1]), -np.array(losses_bpr['train']['bpr'][-1]), marker='o', label='BPR')
plt.plot(-np.array(losses_penalized['train']['nll'][-1]), -np.array(losses_penalized['train']['bpr'][-1]), marker='o', label='Penalized')
plt.title('Training Frontier')
plt.legend()
plt.show()

# %%
mix_model.layers[-1](val_X_THS)
# Out:
# <tf.Tensor: shape=(4, 1), dtype=float32, numpy=
# array([[0.11218371],
#        [0.41130728],
#        [0.3664556 ],
#        [0.11005334]], dtype=float32)>

# %%
mix_model(val_X_THS)
# Out:
# [<tf.Tensor: shape=(100, 12, 2), dtype=float32, numpy=
#  array([[[1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          ...,
#          [0.0000000e+00, 0.0000000e+00],
#          [0.0000000e+00, 2.1345504e-13],
#          [6.4145906e-35, 1.5880117e-22]],
#
#         [[1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          ...,
#          [0.0000000e+00, 2.2063691e-36],
#          [1.5347602e-32, 2.7504011e-20],
#          [0.0000000e+00, 7.9896595e-37]],
#
#         [[1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          ...,
#          [0.0000000e+00, 4.9756957e-29],
#          [0.0000000e+00, 0.0000000e+00],
#          [4.0092460e-30, 2.4079887e-30]],
#
#         ...,
#
#         [[1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          ...,
#          [1.4422261e-05, 2.7863216e-09],
#          [0.0000000e+00, 3.4733319e-13],
#          [3.3685885e-06, 6.7557966e-14]],
#
#         [[1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          ...,
#          [9.3219610e-10, 2.9438246e-27],
#          [1.7640918e-03, 7.8283514e-20],
#          [3.9144747e-05, 5.3374145e-12]],
#
#         [[1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          [1.6688131e-28, 3.8546022e-19],
#          ...,
#          [1.3428053e-24, 7.4796985e-06],
#          [1.7822911e-38, 4.1095073e-38],
#          [2.1165779e-32, 1.6795251e-01]]], dtype=float32)>,
#  <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
#  array([[0.873969  ],
#         [0.12603097]], dtype=float32)>]

# %%
mixture_poi_loss(train_y_TS, preds)
# Out:
# <tf.Tensor: shape=(300, 12), dtype=float32, numpy=
# array([[3.0830662e+00, 3.0830662e+00, 3.0830662e+00, ..., 2.1288426e+00,
#         1.4939419e+01, 7.4566450e+00],
#        [3.0830662e+00, 3.0830662e+00, 3.0830662e+00, ..., 1.0016949e+01,
#         9.8723297e+00, 2.3919154e-06],
#        [3.0830662e+00, 3.0830662e+00, 3.0830662e+00, ..., 1.2917208e+01,
#         2.9280365e+00, 9.6958210e-21],
#        ...,
#        [3.0830662e+00, 3.0830662e+00, 3.0830662e+00, ..., 8.1487730e-02,
#         2.3531229e+01, 1.3449357e+01],
#        [3.0830662e+00, 3.0830662e+00, 3.0830662e+00, ..., 1.7063694e+01,
#         1.0635285e+01, 5.5360909e+01],
#        [3.0830662e+00, 3.0830662e+00, 3.0830662e+00, ..., 8.4530802e+00,
#         1.9098425e+01, 2.7813427e+01]], dtype=float32)>

# %%
train_dataset[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 train_dataset[0]
#
# TypeError: '_BatchDataset' object is not subscriptable
